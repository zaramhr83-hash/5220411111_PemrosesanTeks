# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_zEhAyXwXx4CixPZNRmhfRec8vOsPcI35KnQQ")

# Prepare the Actor input
run_input = {
    "commentsPerPost": 1000,
    "excludePinnedPosts": False,
    "maxRepliesPerComment": 20,
    "postURLs": [
        "https://www.tiktok.com/@jennifer.coppen/video/7553120869896310023?is_from_webapp=1&sender_device=pc"
    ],
    "resultsPerPage": 100
}

# Run the Actor and wait for it to finish
run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)

items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
# Out:
# [apify.tiktok-comments-scraper runId:g3Ual4dhuh1NFUZNJ] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:g3Ual4dhuh1NFUZNJ] -> 2025-10-23T13:46:49.737Z ACTOR: Pulling container image of build N4MyJbgWz0mAr3teM from registry.
# [apify.tiktok-comments-scraper runId:g3Ual4dhuh1NFUZNJ] -> 2025-10-23T13:46:49.738Z ACTOR: Creating container.
# [apify.tiktok-comments-scraper runId:g3Ual4dhuh1NFUZNJ] -> 2025-10-23T13:46:50.047Z ACTOR: Starting container.
# [apify.tiktok-comments-scraper runId:g3Ual4dhuh1NFUZNJ] -> 2025-10-23T13:46:50.274Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-comments-scraper runId:g3Ual4dhuh1NFUZNJ] -> 2025-10-23T13:46:51.802Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.5"}
# ...

# %%
import pandas as pd

df = pd.DataFrame(items)
df
# Out:
#                                            videoWebUrl  \
# 0    https://www.tiktok.com/@jennifer.coppen/video/...
# 1    https://www.tiktok.com/@jennifer.coppen/video/...
# 2    https://www.tiktok.com/@jennifer.coppen/video/...
# 3    https://www.tiktok.com/@jennifer.coppen/video/...
# 4    https://www.tiktok.com/@jennifer.coppen/video/...
# ..                                                 ...
# 995  https://www.tiktok.com/@jennifer.coppen/video/...
# 996  https://www.tiktok.com/@jennifer.coppen/video/...
# 997  https://www.tiktok.com/@jennifer.coppen/video/...
# 998  https://www.tiktok.com/@jennifer.coppen/video/...
# 999  https://www.tiktok.com/@jennifer.coppen/video/...
#
#                                      submittedVideoUrl  \
# 0    https://www.tiktok.com/@jennifer.coppen/video/...
# 1    https://www.tiktok.com/@jennifer.coppen/video/...
# 2    https://www.tiktok.com/@jennifer.coppen/video/...
# 3    https://www.tiktok.com/@jennifer.coppen/video/...
# ...

# %%
df.to_csv('dataTiktok.csv', index=False)

# %%
df.to_excel('dataTiktok.xlsx', index=False)
